# %% [markdown]
# ## Homework 2 - CS348 Spring 2019

# %% [markdown]
# **Description** - This assignment is intended to teach you about exploratory data analysis using python and common data science visualization libraries.

# %% [markdown]
# **Getting Started** - You should complete the assignment using your own installation of Python 3 and the packages numpy, pandas, matplotlib, and seaborn. Download the assignment from Moodle and unzip the file. This will create a directory with this file, 'HW02.ipynb', and a 'data' directory. The data files for each data set are in the 'data' directory.
#
# Note: You may need to install the seaborn visualization library. To do this run `conda install seaborn` or `pip install seaborn` in your terminal.

# %% [markdown]
# **Deliverables** - The assignment has a single deliverable: this jupyter notebook file saved as a pdf. Please answer all coding and writing questions in the body of this file. Once all of the answers are complete, download the file by navigating the following menus: File -> Download as -> PDF via LaTeX. Submit the downloaded pdf file on gradescope.
#
# Note: You will be writing the written repsonses in the same cell block as the coding solution, so make sure to comment out the written responses.

# %% [markdown]
# **Data Sets** - In this assignment, you will conduct an exploratory data analysis on 2 datasets. The first dataset, 'flights', is imported for you from the seaborn library.

# %% [markdown]
# **Academic Honesty Statement** — Copying solutions from external sources (books,
# web pages, etc.) or other students is considered cheating. Sharing your solutions with
# other students is considered cheating. Posting your code to public repositories such as
# GitHub is also considered cheating. Any detected cheating will result in a grade of 0 on
# the assignment for all students involved, and potentially a grade of F in the course.
#
# This academic honesty statement does not restrict you from reading official documentation or using other web resources for understanding the syntax of python, related data science libraries, or properties of distributions.

# %%
# Do not import any other libraries other than those listed here. 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Problem 1 - Flights Dataset

# %% [markdown]
# In this problem you'll analyze a dataset of the monthly number of passengers on US flights from the years 1949 - 1960.

# %% [markdown]
# **Part 1** (3 points)
# Load the 'flights' dataset as a pandas DataFrame and print the first 10 rows of data.

# %%
# Part 1 Solution

# --- write code here ---
flightscsv=pd.read_csv('data/flights.csv')
flights=pd.DataFrame(data=flightscsv)
flights.iloc[0:10]
# Out:
#    Unnamed: 0      month  passengers
# 0           0    January         112
# 1           1   February         118
# 2           2      March         132
# 3           3      April         129
# 4           4        May         121
# 5           5       June         135
# 6           6       July         148
# 7           7     August         148
# 8           8  September         136
# 9           9    October         119

# %% [markdown]
# **Part 2** (12 points)
# Plot a histogram of the number of montly passengers traveling during the summer months. Summer months include June, July, and August. Does the histogram resemble a normal distribution? Provide two justifications for your answer.

# %%
# Part 2 Solution

# --- write code here ---
summerMonths=['June','July','August']
summerFlights=flights[flights.month.isin(summerMonths)]
plot=summerFlights['passengers'].plot.hist()
plt.xlabel("Passengers")
plt.title("Frequency of Number of Flight Passengers During Summer Months")

# --- written response here ---
# The histogram does not resemble a normal distribution. The mean looks to be in the range of 200 to 300 meanwhile
#the median appears to be more like 400. In a normal distribution the mean and median would be the same. 
# Another reason the plot does not look normally distributed is because the data is not evenly distributed around the mean.
#In a normal plot you would see the same frequency to the left of the mean as you would the right. Here the frequency 
#trends downwards as you move up the x axis.
# Out:
# Text(0.5, 1.0, 'Frequency of Number of Flight Passengers During Summer Months')

# %% [markdown]
# **Part 3** (12 points)
# Make a timeseries plot using `sns.lineplot()`. Using this plot, answer the following question: are the rows in the dataset independent and identically distributed (IID)? Why or why not?

# %%
# Part 3 Solution

# --- write code here ---

#unnamed is number of months since January 1949
#SHOULD THIS BE OF SUMMERFLIGHTS OR ALL FLIGHTS?!?!?!?!
lineplot=sns.lineplot(x="Unnamed: 0", y="passengers", data=flights)
lineplot.set(xlabel='Months Since January 1949', ylabel='Number of Passengers')
lineplot.set(title="Airline Passengers Month by Month Since January 1949")
# --- written response here ---
#The data does not appear independent and identically distributed because the number of passengers clearly trends upwards 
#over time. Therefore, the number of passengers is probably dependent on the months since January 1949.
# Out:
# [Text(0.5, 1.0, 'Airline Passengers Month by Month Since January 1949')]

# %% [markdown]
# **Part 4** (20 points)
# Your colleague is trying to predict the total number of passengers who flew in June 1961, one year after the end of the flights dataset. They notice that the average difference between the number of passengers in June and the number passengers in January is 69.92 from 1949 - 1960. Given that they know that 450 passengers flew in January 1961, they predict that there will be 520 passengers flying in June 1961.
#
# Is this a good estimate for the number of passengers flying in June 1961? If not, do you expect it to over- or under-estimate the actual number of passengers? Explain your answer.

# %%
# Part 4 Solution

# --- written response here ---
#It seems that this method would underestimate the actual number of passengers since we have shown that the number of passengers
#has grown consistently over time. More precisely, the average difference calculated here is likely brought down by the earlier
# data where the number of passengers was not so high. We can see this in the lineplot because the difference between each 
#local minimum and local maximum gets larger as time progresses.

# %% [markdown]
# # Problem 2 - Synthetic Data

# %% [markdown]
# In this problem you'll be asked to analyze a synthetic dataset of four variables.

# %% [markdown]
# **Part 1** (3 points)
# Load the 'synthetic' data as a pandas dataframe and print the first 10 rows.

# %%
# Part 1 Solution

# --- write code here ---
syncsv=pd.read_csv('data/synthetic.csv')
syn=pd.DataFrame(data=syncsv)
syn.iloc[0:10]
# Out:
#    Unnamed: 0          a          b          c         d           e
# 0           0  10.590051  26.191885 -30.634067  2.364324  Category 0
# 1           1   8.669480  22.364265 -25.528595  1.558527  Category 0
# 2           2  10.473553  26.396606 -25.777483  1.806674  Category 0
# 3           3   5.946901  17.069787 -19.311699  1.207391  Category 1
# 4           4  11.449457  28.229418 -28.239489  1.054686  Category 1
# 5           5   9.160058  23.213218 -24.035343  1.232872  Category 1
# 6           6  11.768469  28.725059 -31.058865  2.171159  Category 0
# 7           7   7.982466  20.984785 -23.001933  2.712406  Category 0
# 8           8   9.711183  24.984666 -25.254299  1.124860  Category 0
# 9           9   9.705916  24.025878 -22.038090  2.683041  Category 0

# %% [markdown]
# **Part 2** (6 points)
# Use `sns.pairplot()` to make a pairplot of the synthetic dataset. Use colors and/or symbols to visualize the relationship between the categorical and ordinal variables.

# %%
# Part 2 Solution

# --- write code here ---

if(list(syn.columns.values)[0]=="Unnamed: 0"):
    syn=syn.drop(columns="Unnamed: 0")
print("size of synthetic dataset: {}".format(syn.shape))
pplot=sns.pairplot(data=syn, hue='e',kind="reg",markers=["+","o"])
pplot=sns.pairplot(data=syn, kind="reg")
# Out:
# size of synthetic dataset: (1002, 5)

# %% [markdown]
# **Part 3** (10 points)
# For variables a, b, c, and d determine whether its marginal distribution is uniform or normal. Explain your answers.
#
# Hint: Be careful about the `diag_kind` parameter in `sns.lineplot`. The default behaviour is to use a smoothed estimate of the probability density that can sometimes be misleading. None of the marginal distributions are a mixture of normal distributions.

# %%
# Part 3 solution

# --- written response here ---
# a,b and c are normal distributions because the plot of the same variable on x and y axis looks like
#a normal distribution since the majority of data points lie close to the mean and are evenly distributed on each side
#variable d is a uniform distribution. If we plot the data without making a distrinction between the category given by column e,
#we can see that the points fall in a rectangular shape between the values 1 and 3 and not a bell curve.

# %% [markdown]
# **Part 4** (10 points)
# For all pairs of variables (a-b, a-c, etc.) in the synthetic dataset, determine if the two variables are marginally independent. Explain your answers.
#
# Reminder: A random variable X is marginally independent of another random variable Y if knowledge of X does not change the distribution of Y. In other words, X and Y are marginally independent if P(X,Y) = P(X)P(Y) or equivalently P(Y|X) = P(Y).

# %%
# Part 4 solution

# --- written response here ---
# a-b and b-a are not marginally independent. This is because the graphs which plot a and b together both show that the distributions
# are similar to one another. So when a is on the x-axis we observe that as it increases so does b. The same is true when we have b on the x-axis.
# a-c and c-a are not marginally independent. The graph of a as the independent variable (x-axis) shows that when a increases c decreases.
#similarly, if we look at the graph with c on the x-axis we can observe that as it increases a decreases.
# a-d and d-a are marginally independent. This is because when we look at the plot with either acting as the independent variable, we observer
#that the distribution of the dependent variable, the y-axis, does not change with x.

# b-c and c-b are not marginally independent. When either one is the independent variable we can see that the y value is affected
#for example, when b is the x-axis and it increases c decreases. Similarly, if c is the x-axis and it increases, b decreases.
#b-d and d-b are marginally independent. Knowledge of one does not affect the other. The distributions of the values are
#uniform, that is, moving up or down the x-axis does not indicate where the y value is more likely to be.

#c-d and d-c are marginally independent. Knowledge of one does not affect the other. The distributions of the values are
#uniform, that is, moving up or down the x-axis of both plots of c and d does not indicate where the y value is more likely to be.

# %% [markdown]
# **Part 5** (12 points)
# There are 2 outliers in the synthetic dataset. Is it possible to identify these outliers using only the marginal distributions for each of the 4 variables? Why or why not?

# %%
# Part 5 solution

# --- written response here ---
# The outliers are easy to identify here if we look at the plots where the variables are marginally dependent. That is, if we
#observe that knowledge of x affects the value y, causing a consistent trend, then data points which stray far from this trend
# can be labeled outliers.

# %% [markdown]
# **Part 6** (12 points)
# Given your answer to part 5, is it plausible to detect outliers using only visualizations when your dataset contains 1000 columns? Why or why not?

# %%
# Part 6 solution

# --- written response here ---
# No, it would not be reasonable to expect one to be able to notice outliers when there are 1000 columns (variables)
# It was easy to see the outliers here since there were only a few variables so we could look at each plot with a variable 
#acting as the independent and dependent variable (ex. a-b and b-a). When there are 1000 variables we would have 1000 plots
#to consider when searching for an outlier value.
